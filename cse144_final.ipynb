# %% [markdown]
# <a href="https://colab.research.google.com/github/jayjanii/cse-144-kaggle-competition/blob/submission/cse144_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")

user, repo = 'jayjanii', 'cse-144-kaggle-competition'
# %cd /content
# !rm -rf scfinal
# !git clone -b submission https://{user}:{token}@github.com/{user}/{repo}.git
# %cd scfinal

# %%
# !bash run.sh
